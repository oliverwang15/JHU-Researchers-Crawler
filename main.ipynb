# %%
import requests
from lxml import etree
from tqdm import tqdm
import pandas as pd
import traceback

# %%
base_url = "https://www.cs.jhu.edu/faculty/"             # CS
# base_url = "https://engineering.jhu.edu/ams/faculty/"  # AMS

headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36"
}

# %%
response = requests.get(base_url, headers=headers)
response = etree.HTML(response.text)
entity_list = response.xpath("/html/body/div[2]/main/div/div[2]/div/div/div/ul/li")
len(entity_list)
# Out:
# 51

# %%
all = pd.DataFrame()
for entity in tqdm(entity_list, desc="Scraping..."):
    try:
        # A dict to store all the details
        detail_dict = {}

        # Get the url and name from the first page
        url = entity.xpath('./div/div/div/div[1]/div/h2/a/@href')[0]
        name = entity.xpath('./div/div/div/div[1]/div/h2/a/text()')[0]
        detail_dict['name'] = name
        detail_dict['url'] = url

        # Get the details from the second page
        response = requests.get(url, headers=headers)
        response = etree.HTML(response.text)
        meta_details = response.xpath("/html/body/div[2]/main/div/div[1]/div/div/div/div/div/div")

        # Get the details
        for meta_detail in meta_details:
            meta_name = meta_detail.xpath("./div[1]/text()")[0]

            if meta_name == "Education":
                tel = meta_detail.xpath("./div[2]/a/text()")[0]
                detail_dict['tel'] = tel
                email = meta_detail.xpath("./div[3]/a/text()")[0]
                detail_dict['email'] = email

            elif meta_name == "Location":
                location = meta_detail.xpath("./div[2]/div[2]/text()")[0]
                detail_dict['location'] = location

            elif meta_name == "Research Areas":
                research_areas = meta_detail.xpath("./div")[1:]
                research_areas = [area.xpath("./text()")[0] for area in research_areas]
                research_areas = [area.strip() for area in research_areas]
                detail_dict['research_areas'] = ' | '.join(research_areas)

            elif meta_name == "Connect":
                connect_list = meta_detail.xpath("./ul/li")
                for connect in connect_list:
                    connect = connect.xpath("./a")[0]
                    url = connect.xpath("./@href")[0]
                    connect_name = connect.xpath("./span/span[1]/text()")[0]
                    detail_dict[connect_name] = url

        # Get the self introduction
        self_intro = response.xpath("/html/body/div[2]/main/div/div[2]/div/div/div//text()")
        detail_dict['self_intro'] = '\n'.join(self_intro)

        # concat the data
        tmp = pd.DataFrame(detail_dict, index=[0])
        all = pd.concat([all, tmp], ignore_index=True)
    
    except Exception as e:
        message = f"Something went wrong with {name} and the url is {url } \nError: {traceback.format_exc()}\n"
        print(message)

# Save the data
all.to_excel("cs.xlsx", index=False)
# all.to_excel("ams.xlsx", index=False)
all.shape
# Out:
# Scraping...:   0%|          | 0/51 [00:00<?, ?it/s]
# Scraping...: 100%|██████████| 51/51 [00:08<00:00,  6.11it/s]
# (51, 12)

# %%
all
# Out:
#                         name  \
# 0                  Yair Amir
# 1                Raman Arora
# 2         Vladimir Braverman
# 3               Randal Burns
# 4                 Yinzhi Cao
# 5              Anton Dahbura
# 6       Mohammad Ali Darvish
# 7             Michael Dinitz
# 8                Mark Dredze
# 9                  Kevin Duh
# 10              Jason Eisner
# 11             Anjalie Field
# 12                Gagan Garg
# 13           Soudeh Ghorbani
# 14             Matthew Green
# 15             Gregory Hager
# 16  Susan Hohenberger-Waters
# 17           David Hovemeyer
# 18          Chien-Ming Huang
# 19             Abhishek Jain
# 20               Craig Jones
# 21          Peter Kazanzides
# 22           Michael Kazhdan
# 23           Daniel Khashabi
# 24             Philipp Koehn
# 25           S. Rao Kosaraju
# 26         Benjamin Langmead
# 27              Xiangyang Li
# 28                    Xin Li
# 29         Thomas Lippincott
# 30                  Anqi Liu
# 31               Ali Madooei
# 32    Alejandro Martin-Gomez
# 33           Sara Miner More
# 34               Aviel Rubin
# 35           Krishan Sabnani
# 36           Steven Salzberg
# 37               Suchi Saria
# 38            Michael Schatz
# 39           Joanne Selinski
# 40             Ilya Shpitser
# 41           Patricio Simari
# 42               Scott Smith
# 43          Alexander Szalay
# 44            Russell Taylor
# 45          Mathias Unberath
# 46        Benjamin van Durme
# 47            Lanier Watkins
# 48                Ziang Xiao
# 49            David Yarowsky
# 50               Alan Yuille
#
#                                                   url  \
# 0           https://www.cs.jhu.edu/faculty/yair-amir/
# 1         https://www.cs.jhu.edu/faculty/raman-arora/
# 2   https://www.cs.jhu.edu/faculty/vladimir-braver...
# 3        https://www.cs.jhu.edu/faculty/randal-burns/
# 4          https://www.cs.jhu.edu/faculty/yinzhi-cao/
# 5       https://www.cs.jhu.edu/faculty/anton-dahbura/
# 6   https://www.cs.jhu.edu/faculty/mohammad-ali-da...
# 7      https://www.cs.jhu.edu/faculty/michael-dinitz/
# 8         https://www.cs.jhu.edu/faculty/mark-dredze/
# 9           https://www.cs.jhu.edu/faculty/kevin-duh/
# 10       https://www.cs.jhu.edu/faculty/jason-eisner/
# 11      https://www.cs.jhu.edu/faculty/anjalie-field/
# 12         https://www.cs.jhu.edu/faculty/gagan-garg/
# 13    https://www.cs.jhu.edu/faculty/soudeh-ghorbani/
# 14      https://www.cs.jhu.edu/faculty/matthew-green/
# 15      https://www.cs.jhu.edu/faculty/gregory-hager/
# 16  https://www.cs.jhu.edu/faculty/susan-hohenberg...
# 17    https://www.cs.jhu.edu/faculty/david-hovemeyer/
# 18   https://www.cs.jhu.edu/faculty/chien-ming-huang/
# 19      https://www.cs.jhu.edu/faculty/abhishek-jain/
# 20      https://www.cs.jhu.edu/faculty/craig-jones-3/
# 21   https://www.cs.jhu.edu/faculty/peter-kazanzides/
# 22    https://www.cs.jhu.edu/faculty/michael-kazhdan/
# 23    https://www.cs.jhu.edu/faculty/daniel-khashabi/
# 24      https://www.cs.jhu.edu/faculty/philipp-koehn/
# 25     https://www.cs.jhu.edu/faculty/s-rao-kosaraju/
# 26  https://www.cs.jhu.edu/faculty/benjamin-langmead/
# 27       https://www.cs.jhu.edu/faculty/xiangyang-li/
# 28             https://www.cs.jhu.edu/faculty/xin-li/
# 29  https://www.cs.jhu.edu/faculty/thomas-lippincott/
# 30     https://www.cs.jhu.edu/faculty/anqi-angie-liu/
# 31        https://www.cs.jhu.edu/faculty/ali-madooei/
# 32  https://www.cs.jhu.edu/faculty/alejandro-marti...
# 33    https://www.cs.jhu.edu/faculty/sara-miner-more/
# 34        https://www.cs.jhu.edu/faculty/aviel-rubin/
# 35  https://www.cs.jhu.edu/faculty/krishan-sabnani-2/
# 36    https://www.cs.jhu.edu/faculty/steven-salzberg/
# 37        https://www.cs.jhu.edu/faculty/suchi-saria/
# 38     https://www.cs.jhu.edu/faculty/michael-schatz/
# 39    https://www.cs.jhu.edu/faculty/joanne-selinski/
# 40      https://www.cs.jhu.edu/faculty/ilya-shpitser/
# 41    https://www.cs.jhu.edu/faculty/patricio-simari/
# 42        https://www.cs.jhu.edu/faculty/scott-smith/
# 43   https://www.cs.jhu.edu/faculty/alexander-szalay/
# 44     https://www.cs.jhu.edu/faculty/russell-taylor/
# 45   https://www.cs.jhu.edu/faculty/mathias-unberath/
# 46  https://www.cs.jhu.edu/faculty/benjamin-van-du...
# 47     https://www.cs.jhu.edu/faculty/lanier-watkins/
# 48         https://www.cs.jhu.edu/faculty/ziang-xiao/
# 49     https://www.cs.jhu.edu/faculty/david-yarowsky/
# 50        https://www.cs.jhu.edu/faculty/alan-yuille/
#
#                     location  \
# 0            209 Malone Hall
# 1            331 Malone Hall
# 2                        NaN
# 3            163 Malone Hall
# 4            305 Malone Hall
# 5            167 Malone Hall
# 6            205 Malone Hall
# 7            217 Malone Hall
# 8                        NaN
# 9         226 Hackerman Hall
# 10       324C Hackerman Hall
# 11           333 Malone Hall
# 12                Malone 211
# 13           223 Malone Hall
# 14           313 Malone Hall
# 15                       NaN
# 16                       NaN
# 17           337 Malone Hall
# 18           317 Malone Hall
# 19           315 Malone Hall
# 20               Malone 338
# 21        120 Hackerman Hall
# 22           229 Malone Hall
# 23       316B Hackerman Hall
# 24        227 Hackerman Hall
# 25           213 Malone Hall
# 26           329 Malone Hall
# 27                       NaN
# 28           215 Malone Hall
# 29                       NaN
# 30           233 Malone Hall
# 31           227 Malone Hall
# 32            Hackerman 128
# 33           221 Malone Hall
# 34           309 Malone Hall
# 35                       NaN
# 36  S261 Wyman Park Building
# 37           333 Malone Hall
# 38           323 Malone Hall
# 39           225 Malone Hall
# 40           321 Malone Hall
# 41                       NaN
# 42           219 Malone Hall
# 43            Bloomberg 515
# 44        127 Hackerman Hall
# 45        Hackerman Hall B05
# 46       226C Hackerman Hall
# 47                       NaN
# 48                       NaN
# 49       324G Hackerman Hall
# 50                Clark 324B
#
#                                        research_areas  \
# 0   Critical infrastructure; large-scale survivabl...
# 1   Machine learning | Statistical signal processi...
# 2   Algorithms for massive data | Randomized and s...
# 3                                                 NaN
# 4   Security and Privacy of Machine Learning | Web...
# 5   Assured Autonomy | Information Security | Faul...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Natural Language Processing | Computational So...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  Medical image processing | Artificial intellig...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  Computational genomics | Sequence alignment | ...
# 27                                                NaN
# 28                                                NaN
# 29  Computational intelligence for the humanities ...
# 30  Reliable and human-compatible AI systems | Int...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Communication protocols | Computer networks | ...
# 36  Biomedical Data Science | Genomics and Systems...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41  Geometry processing | Shape analysis | Segment...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46  Artificial Intelligence | Natural Language Pro...
# 47  Critical Infrastructure Protection | Network S...
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
#
#                                     Publications  \
# 0       http://www.dsn.jhu.edu/publications.html
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17  https://dblp.org/pers/h/Hovemeyer:David.html
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
# 30                                           NaN
# 31                                           NaN
# 32                                           NaN
# 33                                           NaN
# 34                                           NaN
# 35                                           NaN
# 36                                           NaN
# 37                                           NaN
# 38                                           NaN
# 39                                           NaN
# 40                                           NaN
# 41                                           NaN
# 42                                           NaN
# 43                                           NaN
# 44                                           NaN
# 45                                           NaN
# 46                                           NaN
# 47                                           NaN
# 48                                           NaN
# 49                                           NaN
# 50                                           NaN
#
#                                           Website  \
# 0               https://www.cs.jhu.edu/~yairamir/
# 1         https://www.cs.jhu.edu/~raman/Home.html
# 2                   https://www.cs.jhu.edu/~vova/
# 3                  https://randalburns.github.io/
# 4                          https://yinzhicao.org/
# 5                                             NaN
# 6                https://www.cs.jhu.edu/~darvish/
# 7                https://www.cs.jhu.edu/~mdinitz/
# 8                https://www.cs.jhu.edu/~mdredze/
# 9                    http://cs.jhu.edu/~kevinduh/
# 10                 https://www.cs.jhu.edu/~jason/
# 11                    https://anjalief.github.io/
# 12                                            NaN
# 13                        http://soudeh.net/#home
# 14               http://spar.isi.jhu.edu/~mgreen/
# 15                  https://www.cs.jhu.edu/hager/
# 16                 https://www.cs.jhu.edu/~susan/
# 17                https://www.cs.jhu.edu/~daveho/
# 18               https://www.cs.jhu.edu/~cmhuang/
# 19              https://www.cs.jhu.edu/~abhishek/
# 20                           https://rail.jhu.edu
# 21                   https://smarts.lcsr.jhu.edu/
# 22                 https://www.cs.jhu.edu/~misha/
# 23                     http://danielkhashabi.com/
# 24                   https://www.cs.jhu.edu/~phi/
# 25              https://www.cs.jhu.edu/~kosaraju/
# 26   https://langmead-lab.org/teaching-materials/
# 27               https://isi.jhu.edu/people/xyli/
# 28               https://www.cs.jhu.edu/~lixints/
# 29                  http://www.logical-space.org/
# 30            https://anqiliu-ai.github.io/#about
# 31                                            NaN
# 32                                            NaN
# 33                  https://www.cs.jhu.edu/~more/
# 34                https://avirubin.com//Home.html
# 35                                            NaN
# 36  https://www.forbes.com/sites/stevensalzberg/.
# 37                    https://suchisaria.jhu.edu/
# 38                         http://schatz-lab.org/
# 39                https://www.cs.jhu.edu/~joanne/
# 40                 https://www.cs.jhu.edu/~ilyas/
# 41                                            NaN
# 42                 https://www.cs.jhu.edu/~scott/
# 43               http://www.sdss.jhu.edu/~szalay/
# 44                   https://www.cs.jhu.edu/~rht/
# 45                        http://deep.cs.jhu.edu/
# 46              https://www.cs.jhu.edu/~vandurme/
# 47                                            NaN
# 48                                            NaN
# 49              https://www.cs.jhu.edu/~yarowsky/
# 50               https://www.cs.jhu.edu/~ayuille/
#
#                                            self_intro  \
# 0   \n\t\t\t\t\t\nYair Amir, professor emeritus of...
# 1   \n\t\t\t\t\t\nRaman Arora is an assistant prof...
# 2   \n\t\t\t\t\t\nVladimir Braverman is an associa...
# 3   \n\t\t\t\t\t\nRandal Burns is a professor and ...
# 4   \n\t\t\t\t\t\nYinzhi Cao is an assistant profe...
# 5   \n\t\t\t\t\t\nAnton (Tony) Dahbura is the exec...
# 6   \n\t\t\t\t\t\nMohammed Ali Darvish is a senior...
# 7   \n\t\t\t\t\t\nMichael Dinitz is an associate p...
# 8   \n\t\t\t\t\t\nMark Dredze, the John C. Malone ...
# 9   \n\t\t\t\t\t\nKevin Duh is an assistant resear...
# 10  \n\t\t\t\t\t\nJason Eisner, a professor of com...
# 11  \n\t\t\t\t\t\nAnjalie Field is an assistant pr...
# 12  \n\t\t\t\t\t\nGagan Garg joins the Department ...
# 13  \n\t\t\t\t\t\nSoudeh Ghorbani, an assistant pr...
# 14  \n\t\t\t\t\t\nMatthew D. Green, an associate p...
# 15  \n\t\t\t\t\t\nGregory D. Hager is the Mandell ...
# 16  \n\t\t\t\t\t\nSusan Hohenberger, a research pr...
# 17  \n\t\t\t\t\t\nDavid Hovemeyer is an associate ...
# 18  \n\t\t\t\t\t\nChien-Ming Huang, a John C. Malo...
# 19  \n\t\t\t\t\t\nAbhishek Jain, an associate prof...
# 20  \n\t\t\t\t\t\nCraig Jones is interested in med...
# 21  \n\t\t\t\t\t\nPeter Kazanzides, a research pro...
# 22  \n\t\t\t\t\t\nMichael (Misha) Kazhdan, a profe...
# 23  \n\t\t\t\t\t\nDaniel Khashabi is an assistant ...
# 24  \n\t\t\t\t\t\nPhilipp Koehn, professor of comp...
# 25  \n\t\t\t\t\t\nRao Kosaraju, the Edward J. Scha...
# 26  \n\t\t\t\t\t\nBen Langmead, the 2016  recipien...
# 27  \n\t\t\t\t\t\nXiangyang Li has been working fo...
# 28  \n\t\t\t\t\t\nXin Li, an associate professor o...
# 29  \n\t\t\t\t\t\nThomas (Tom) Lippincott is an as...
# 30  \n\t\t\t\t\t\nAnqi (Angie) Liu is an assistant...
# 31  \n\t\t\t\t\t\nAli Madooei, a senior lecturer i...
# 32  \n\t\t\t\t\t\nAlejandro Martin-Gomez is an ass...
# 33  \n\t\t\t\t\t\nSarah Miner Moore is an associat...
# 34  \n\t\t\t\t\t\nAvi Rubin, a professor emeritus ...
# 35  \n\t\t\t\t\t\nKrishan Sabnani is a networking ...
# 36  \n\t\t\t\t\t\nSteven L. Salzberg\n is a Bloomb...
# 37  \n\t\t\t\t\t\nSuchi Saria is the John C. Malon...
# 38  \n\t\t\t\t\t\nMichael Schatz, Bloomberg Distin...
# 39  \n\t\t\t\t\t\nJoanne Selinski is an associate ...
# 40  \n\t\t\t\t\t\nIlya Shpitser, a John C. Malone ...
# 41  \n\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPatr...
# 42  \n\t\t\t\t\t\nScott Smith, a professor of comp...
# 43  \n\t\t\t\t\t\nAlexander Szalay is a Bloomberg ...
# 44  \n\t\t\t\t\t\nRussell H. Taylor is the John C....
# 45  \n\t\t\t\t\t\nMathias Unberath is an assistant...
# 46  \n\t\t\t\t\t\nBenjamin Van Durme is an assista...
# 47  \n\t\t\t\t\t\nLanier Watkins, chair of the Joh...
# 48  \n\t\t\t\t\t\nZiang Xiao is an assistant profe...
# 49  \n\t\t\t\t\t\nDavid Yarowsky is a professor in...
# 50  \n\t\t\t\t\t\nAlan Yuille is a Bloomberg Disti...
#
#                                        Google Scholar  \
# 0                                                 NaN
# 1   https://scholar.google.com/citations?user=Spe0...
# 2   https://scholar.google.com/citations?user=DTth...
# 3   https://scholar.google.com/citations?user=rTJT...
# 4   https://scholar.google.com/citations?user=0jBP...
# 5   https://scholar.google.com/citations?user=-s3H...
# 6   https://scholar.google.com/citations?user=0Xk_...
# 7   https://scholar.google.com/citations?user=Q2yN...
# 8   https://scholar.google.com/citations?user=7jNk...
# 9                                                 NaN
# 10  https://scholar.google.com/citations?user=tjb2...
# 11  https://scholar.google.com/citations?user=WQO8...
# 12                                                NaN
# 13  https://scholar.google.com/citations?user=r7ky...
# 14  https://scholar.google.com/citations?user=X0XW...
# 15                                                NaN
# 16  https://scholar.google.com.sg/citations?user=E...
# 17                                                NaN
# 18  https://scholar.google.com/citations?user=0kTe...
# 19  https://scholar.google.com/citations?user=xjkm...
# 20   https://scholar.google.com/citations?hl=en&us...
# 21  https://scholar.google.com/citations?user=nNU3...
# 22  https://scholar.google.com/citations?user=soUq...
# 23  https://scholar.google.com/citations?user=pK2k...
# 24  https://scholar.google.com/citations?user=OsIZ...
# 25  https://dblp.uni-trier.de/pers/k/Kosaraju:S=_R...
# 26  https://scholar.google.com/citations?user=2JMa...
# 27                                                NaN
# 28  https://scholar.google.com/citations?user=OUS_...
# 29                                                NaN
# 30                                                NaN
# 31  https://scholar.google.com/citations?user=VMKT...
# 32                                                NaN
# 33  https://scholar.google.com/citations?user=KPw5...
# 34  https://scholar.google.com/citations?user=KWez...
# 35  https://scholar.google.com/citations?user=OWfY...
# 36  https://scholar.google.com/citations?user=sUVe...
# 37  https://scholar.google.com/citations?user=FZLH...
# 38  https://scholar.google.com/citations?user=rcs6...
# 39                                                NaN
# 40  https://scholar.google.com/citations?user=ZyKr...
# 41                                                NaN
# 42  https://scholar.google.com/citations?user=bRjJ...
# 43  https://scholar.google.com/citations?user=rUiW...
# 44  https://scholar.google.com/citations?user=Ph16...
# 45  https://scholar.google.de/citations?user=1bd5m...
# 46  https://scholar.google.com/citations?user=wIuj...
# 47  https://scholar.google.com/citations?user=STJv...
# 48                                                NaN
# 49  https://scholar.google.com/citations?user=gaO-...
# 50  https://scholar.google.com/citations?user=FJ-h...
#
#                                 Twitter  \
# 0                                   NaN
# 1    https://twitter.com/RamanArora_JHU
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7           https://twitter.com/mdinitz
# 8           https://twitter.com/mdredze
# 9                                   NaN
# 10        https://twitter.com/adveisner
# 11        https://twitter.com/anjalie_f
# 12                                  NaN
# 13                                  NaN
# 14  https://twitter.com/matthew_d_green
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18  https://twitter.com/chienming_huang
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23   https://twitter.com/DanielKhashabi
# 24                                  NaN
# 25                                  NaN
# 26      https://twitter.com/benlangmead
# 27                                  NaN
# 28                                  NaN
# 29                                  NaN
# 30                                  NaN
# 31                                  NaN
# 32                                  NaN
# 33                                  NaN
# 34         https://twitter.com/avirubin
# 35                                  NaN
# 36  https://twitter.com/stevensalzberg1
# 37       https://twitter.com/suchisaria
# 38      https://twitter.com/mike_schatz
# 39                                  NaN
# 40                                  NaN
# 41                                  NaN
# 42                                  NaN
# 43                                  NaN
# 44                                  NaN
# 45  https://twitter.com/MathiasUnberath
# 46     https://twitter.com/ben_vandurme
# 47                                  NaN
# 48                                  NaN
# 49                                  NaN
# 50                                  NaN
#
#                                            LinkedIn  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12  https://in.linkedin.com/in/gagan-garg-0b139b1bb
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# 30                                              NaN
# 31                                              NaN
# 32                                              NaN
# 33                                              NaN
# 34                                              NaN
# 35                                              NaN
# 36                                              NaN
# 37                                              NaN
# 38                                              NaN
# 39                                              NaN
# 40                                              NaN
# 41                                              NaN
# 42                                              NaN
# 43                                              NaN
# 44                                              NaN
# 45                                              NaN
# 46                                              NaN
# 47                                              NaN
# 48                                              NaN
# 49                                              NaN
# 50                                              NaN
#
#                              Personal Website  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14  https://blog.cryptographyengineering.com/
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                        NaN
# 45                                        NaN
# 46                                        NaN
# 47                                        NaN
# 48                                        NaN
# 49                                        NaN
# 50                                        NaN
#
#                            Lab Website
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26        http://www.langmead-lab.org/
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
# 30                                 NaN
# 31                                 NaN
# 32                                 NaN
# 33                                 NaN
# 34                                 NaN
# 35                                 NaN
# 36            http://salzberg-lab.org/
# 37                                 NaN
# 38                                 NaN
# 39                                 NaN
# 40                                 NaN
# 41                                 NaN
# 42                                 NaN
# 43                                 NaN
# 44  https://ciis.lcsr.jhu.edu/doku.php
# 45                                 NaN
# 46                                 NaN
# 47                                 NaN
# 48                                 NaN
# 49                                 NaN
# 50                                 NaN
